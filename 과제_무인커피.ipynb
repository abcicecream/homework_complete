# %%
# 커피 자판기(무인) 프로그램 작성 
# 1 플로 차트 --기획
# 2 프로그램

# %%
menu = ['아메리카노','카페라테','카푸치노']

# %%
print(menu)
a = input('위 메뉴 중 하나를 하세요: ')
b = input('아이스와 핫 중 선택하세요: ')
print(b+a,'추출을 시작합니다.\n.\n.\n.\n주문하신',b+a,'나왔습니다.')
# Out:
# ['아메리카노', '카페라테', '카푸치노']
# 위 메뉴 중 하나를 하세요:  아메리카노
# 아이스와 핫 중 선택하세요:  핫
# 핫아메리카노 추출을 시작합니다.
# .
# .
# .
# 주문하신 핫아메리카노 나왔습니다.

# %%
# menu = ['아메리카노','카페라테','카푸치노']
# quan = [100,100,100]
menu2 = {'아메리카노':100,'카페라테':0,'카푸치노':100}
# print(menu)
# a = input('위 메뉴 중 하나를 하세요: ')
# if a=='아메리카노' or '카페라테' or '카푸치노':
#     if menu2[a] > 0:
#         b = input('아이스와 핫 중 선택하세요: ')
#         if b=='핫' or '아이스':
#             print(b+a,'추출을 시작합니다.\n.\n.\n.\n주문하신',b+a,'나왔습니다.')
#             menu2[a] -= 1
#             print(menu2)
#         else:
#             print('잘못 입력하셨습니다. 아이스와 핫 중 골라주세요.')
#     else:
#         print('재고가 부족합니다. 다시 골라주세요.')
# else:
#     print('잘못 입력하셨습니다. 메뉴 중 골라주세요.')

a = input('위 메뉴 중 하나를 하세요: ')
try:
    if a in menu2.keys():
        if menu2[a] > 0:
            b = input('아이스와 핫 중 선택하세요: ')
            if b=='핫' or '아이스':
                print(b+a,'추출을 시작합니다.\n.\n.\n.\n주문하신',b+a,'나왔습니다.')
                menu2[a] -= 1
                print(menu2)
            else:
                print('잘못 입력하셨습니다. 아이스와 핫 중 골라주세요.')
        else:
            print('재고가 부족합니다. 다시 골라주세요.')
    else:
        raise NotImplementedError
except NotImplementedError:
    print('잘못 입력하셨습니다.')
# Out:
# 위 메뉴 중 하나를 하세요:  카페라테
# 재고가 부족합니다. 다시 골라주세요.

# %%
menu2.keys()
# Out:
# dict_keys(['아메리카노', '카페라테', '카푸치노'])
